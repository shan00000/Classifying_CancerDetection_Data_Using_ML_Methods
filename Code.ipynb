# %% [markdown]
# Importing the libraries necessory

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Loading the dataset

# %%
data = pd.read_csv("Cancer_Data.csv")

# %% [markdown]
# ### Performing an EDA on the data

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
display(data.columns)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# it looks like unnamed:32 and Id are not needed for the purpose of the project therefore we will drop these coloumns

# %%
data = data.drop(columns=['id','Unnamed: 32'])
display(data.columns)
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ### Visualing Data

# %%
numericaldata = data.select_dtypes(include=np.number)

fig, axs = plt.subplots(6,5,figsize=(20,60))

for colNum, ax in enumerate(axs.flat):
    tempData = numericaldata.iloc[:,colNum]
    tempData = tempData.dropna()
    ax.plot(tempData)
    ax.set_title(numericaldata.columns[colNum])
    
plt.tight_layout()

# %%
print(f"data has total of {len(data.columns)} columns")
print(f"data has total of {len(data.select_dtypes(include=np.number).columns)} Numerical columns")

numericaldata = data.select_dtypes(include=np.number)

fig, axs = plt.subplots(6,5,figsize=(20,60))

for colNum, ax in enumerate(axs.flat):
    tempData = numericaldata.iloc[:,colNum]
    tempData = tempData.dropna()
    ax.boxplot(tempData)
    ax.set_title(numericaldata.columns[colNum])
    
plt.tight_layout()
# Out:
# data has total of 31 columns
# data has total of 30 Numerical columns

# %% [markdown]
# It looks like the data may contain a outlier a issue however we will see if the model is able to deal with these outliers

# %%
print(pd.unique(data["diagnosis"]))
# Out:
# ['M' 'B']

# %% [markdown]
# ### Spliting the data

# %%
y = data['diagnosis']
x = data.drop(columns=['diagnosis'])
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,shuffle=True)

# %% [markdown]
# ### Scaling the data and encording data

# %%
# Scaling
scaler = StandardScaler()
scaler.fit(xtrain)
xtrain = scaler.transform(xtrain)
xtest = scaler.transform(xtest)
# Label encording 
encorder = LabelEncoder()
encorder.fit(ytrain)
ytrain = encorder.transform(ytrain)
ytest = encorder.transform(ytest)

# %% [markdown]
# # Model
